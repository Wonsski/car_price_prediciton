# %%
# !pip install --upgrade tables

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading data

# %%
DATA_PATH = 'data/car.h5'

# %%
df = pd.read_hdf(DATA_PATH)
df.shape
# Out:
# (106494, 155)

# %% [markdown]
# Example data

# %%
df.sample(5)
# Out:
#                                               breadcrumb  ... car_id
# 63542                            [Osobowe, Škoda, RAPID]  ...  63542
# 80272                           [Osobowe, Hyundai, Getz]  ...  80272
# 71596                          [Osobowe, Chrysler, 300C]  ...  71596
# 23228  [Osobowe, Toyota, Avensis, Toyota Avensis II (...  ...  23228
# 8053   [Osobowe, Mercedes-Benz, Vito, Mercedes-Benz V...  ...   8053
#
# [5 rows x 155 columns]

# %% [markdown]
# # Data visualization

# %%
df.price_value.hist(bins=100)

# %%
def group_bar_plot(groupby,argument='price_value',funkcje=[np.mean,np.median,np.size],sort='mean',top=50):
  return (
      df
      .groupby(groupby)[argument]
      .agg(funkcje)
      .sort_values(by=sort,ascending=False)
      .head(top)
  ).plot(kind='bar',figsize=(15,5),subplots=True)

# %%
group_bar_plot('param_color');

# %%
group_bar_plot('param_year',sort='size');

# %%
group_bar_plot('param_moc',sort='median');
